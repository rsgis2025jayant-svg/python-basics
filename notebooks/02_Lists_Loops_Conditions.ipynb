# %% [markdown]
# <a href="https://colab.research.google.com/github/rsgis2025jayant-svg/python-basics/blob/main/notebooks/02_Lists_Loops_Conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 2 – Lists, Loops, and Conditions (Google Colab Edition)
# This notebook covers Python lists, loops, and conditional statements.

# %% [markdown]
# ## 1. Lists in Python
# ### 🔶 Task 1.1 – Create a weekly SST list

# %%
# TODO: Create your SST list and print first, last, and length.
sst = [24 , 23, 25, 26, 24, 23]

print("First value:",sst[0])
print("Last value:",sst[5] )
print("Length of list:", len(sst) )
# Out:
# First value: 24
# Last value: 23
# Length of list: 6

# %% [markdown]
# ## 2. Loops (for-loops)
# ### 🔶 Task 2.1 – Print each value

# %%
# TODO: Print each SST value with day number.
sst = [24 , 23, 25, 26, 24, 23]
for i in range(len(sst)):
    temp = sst[i]
    # print Day X: value
day = 1
for temp in sst:
    print("Day", day, ":", temp)
    day += 1
# Out:
# Day 1 : 24
# Day 2 : 23
# Day 3 : 25
# Day 4 : 26
# Day 5 : 24
# Day 6 : 23

# %% [markdown]
# ## 3. Computing Mean using Loop
# ### 🔶 Task 3.1 – Compute mean SST manually

# %%
sst = [24 , 23, 25, 26, 24, 23]
total = sum(sst)


for temp in sst:
    pass

mean_sst = total/len(sst)
print("Mean SST (loop):", mean_sst)
print("Mean SST (built-in):", sum(sst)/len(sst))
# Out:
# Mean SST (loop): 24.166666666666668
# Mean SST (built-in): 24.166666666666668

# %% [markdown]
# ## 4. Conditions: HOT or NORMAL days
# ### 🔶 Task 4.1 – Classify SST days

# %%
sst = [24 , 23, 25, 26, 24, 23]
threshold = 24

for i in range(len(sst)):
    temp = sst[i]
    day = i + 1
    # TODO: write if condition here
    if temp > threshold:
        print("Day", day, ": HOT")
    if temp <= threshold:
        print("Day", day, ": NORMAL")
# Out:
# Day 1 : NORMAL
# Day 2 : NORMAL
# Day 3 : HOT
# Day 4 : HOT
# Day 5 : NORMAL
# Day 6 : NORMAL

# %% [markdown]
# ## 5. Filtering SST values
# ### 🔶 Task 5.1 – Create HOT and NORMAL SST lists

# %%
sst = [24 , 23, 25, 26, 24, 23]
threshold= 24
hot_sst = []
normal_sst = []
for i in range(len(sst)):
    temp = sst[i]
    if temp > threshold:
        hot_sst.append(temp)

    if temp <= threshold:
        normal_sst.append(temp)

print("Hot SST values:", hot_sst)
print("Normal SST values:", normal_sst)
# Out:
# Hot SST values: [25, 26]
# Normal SST values: [24, 23, 24, 23]

# %% [markdown]
# ## 6. Mini Task – Rainfall classification
# ### 🔶 Task 6.1 – Classify rainfall intensity

# %%
rain = [0.0, 12.5, 34.0, 2.0, 0.0, 55.1, 8.4]

no_rain = 0
light = 0
moderate = 0
heavy = 0

for r in rain:
    if r == 0.0:
        no_rain += 1
    if r > 0.0 and r <= 10.0:
        light += 1
    if r > 10.0 and r <= 30.0:
        moderate += 1
    if r > 30.0:
        heavy += 1

print("No rain days:", no_rain)
print("Light rain days:", light)
print("Moderate rain days:", moderate)
print("Heavy rain days:", heavy)
# Out:
# No rain days: 2
# Light rain days: 2
# Moderate rain days: 1
# Heavy rain days: 2

# %% [markdown]
# ## 7. Reflection
# Write 3–5 sentence answers to the reflection questions here.
